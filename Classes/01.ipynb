# %% [markdown]
# Click here to practice in **colab**.
# <a href="https://colab.research.google.com/github/MAR-Jemim/python_mini_course/blob/main/Classes/01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Class 01: Introduction and few Operators
# ---
# The **Python console** (also called the Python interactive shell or REPL)
# lets you type Python code and immediately see the result.
#
# A Jupyter Notebook works similarly: you write code in a cell and run it to see the output.
#
# We can use console for quick calculation.

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# ### Operators
# Every symbol that does something is called an **operator**.
#
# `2 + 2 = 4`
#
# Here, which one is **operand** and which one is **operator**?
# And, we call it an **addition operation**.
#
# Operators can be categorized in different ways.
#
# These can be differentiated by how many operands they are taking:
# - Unary operator: `+, -, not` etc
# - Binary operator: `+, -, *, /, and, or` etc
# - Ternary operator: `if ... else`
#
# Or these can be separated by what they are doing:
# - Mathematical operator: Does math. The usual suspects: `+`, `-`, `*`, `/`, `//`, `%`, `**`.
# - Assignment operator: Puts a value into a variable. Example: `=`. Its cousins like `+=`, `-=`, `*=`, etc., update and assign in one go.
# - Membership operator: Checks whether something is inside another thing. Examples: `in`, `not in`.
# - Comparison operator: Compares values and answers with `True` or `False`. Examples: `==`, `!=`, `<`, `>`, `<=`, `>=`.
# - Logical operator: Combines or flips boolean values. Examples: `and`, `or`, `not`.
# - Bitwise operator: Works directly with bits. Examples: `&`, `|`, `^`, `~`, `<<`, `>>`. (Don't worry, we'll meet them later. 👀)
# - Identity operator: Checks whether two names point to the exact same object. Examples: `is`, `is not`.
#
# > 💡 **Operator** does the work. **Operand** is what the operator works on.
#
# For example:
#
# ```python
# 10 + 5
# ```
#
# - `+` → operator
# - `10` and `5` → operands
#
# Simple, right? Operators are the verbs of Python—they make things happen.

# %% [markdown]
# ### Mathematical operators
# | Symbols  | Operators       |
# |:--------:|-----------------|
# |    +     | Addition        |
# |    -     | Subtraction     |
# |    *     | Multiplication  |
# |    **    | Exponentiation  |
# |    /     | True Division   |
# |    //    | Floor Division  |
# |    %     | Modulo Division |

# %% [markdown]
# ```python
# # this line is a comment which is ignored by python.
#
# 16 +  5      # equals 21
# 16 -  5      # equals 11
# 16 *  5      # equals 80
# 16 ** 5      # equals 1048576
#        # base ** power
# 16 /  5      # equals 3.2
#        # actual division
# 16 // 5      # equals 3
#        # only whole number
# 16 %  5      # equals 1
#        # remainder
# ```
# > Now try it yourself below.

# %%
16 **  5
# Out:
# 1048576

# %% [markdown]
# powered by `//>_<` and [`proBOT`](https://codeforces.com/profile/probot001)
