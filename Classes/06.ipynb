# %% [markdown]
# <a href="https://colab.research.google.com/github/MAR-Jemim/python_mini_course/blob/main/Classes/06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Class 06: Collections
#
# ```mermaid
# flowchart TD
#     A[Start] --> B{Is it valid?}
#     B ---->|Yes| C[Continue]
#     B -->|No| D[Fix it]
#     D --> B
# ```
