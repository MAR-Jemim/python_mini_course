# %% [markdown]
# <a href="https://colab.research.google.com/github/MAR-Jemim/python_mini_course/blob/main/Classes/04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Class 04: Taking user input
