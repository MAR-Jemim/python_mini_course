# %% [markdown]
# <a href="https://colab.research.google.com/github/MAR-Jemim/python_mini_course/blob/main/Classes/03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Class 03: Variables and Data Types
# ---
# ### What we'll learn today
#
# - ✔️ What is a variable?
# - ✔️ Data types
# - ✔️ Assignment operators
#
# In our last classes we have learned how to **calculate and show** our results.
#
# ***Have you submitted your Assignment?***
#
# If you have, I think writing
# >*"Supercalifragilisticexpialidocious is a fascinating word. When I first learned Supercalifragilisticexpialidocious, I thought it was impossible to pronounce. After practicing Supercalifragilisticexpialidocious several times, the word became easier to remember. Now, Supercalifragilisticexpialidocious reminds me that difficult things can become simple practice."*
#
# was a bit painful if you have typed it yourself. Especially the word **Supercalifragilisticexpialidocious**. At some point, you wished to copy and paste it.
#
# In today's lesson we are going to learn the programming version of **copy and paste**.
#
# <br>
#
# ### Variable
# Variable is used to **store** value under a **name** to use the value
# later as much as needed.
# Python variables loo like this.
# ```python
# # name = value
# word = "Supercalifragilisticexpialidocious"
# pi = 3.1415926535897932384626433832
# mark = 76
# grade = 'A'
# grade_point = 3.50
# cgpa = 23 / 7
# passed = True
# ```
# There are some rules for naming a variable:
# - You can use `A-Z`, `a-z`, `0-9`, `_`.
# - You can not start a name with **number**. ~~1st~~, ~~53~~
# - You can not use **space**, or any other **symbols**.
# - You can not use some reserved **keywords** like `print, if, pass, True,
# while` etc.
#
# For example: `roll_1, PASS, res, _res, Res, rES, very_long_name` etc.
#
# You should try writing some variables.

# %%
name = "Akram Hosen Khan Bahadur Chowdhury"
# Akram sir was really a good teacher to me 😢.
result = 2 * 3 ** 3 + 9

print(name)
print(result, result, result)
# Out:
# Akram Hosen Khan Bahadur Chowdhury
# 63 63 63

# %% [markdown]
# There are several types of data to be stored.
# The **data types** are:
# 1. **int** (Integer: Whole number)
# 2. **float** (Float: Fractional number)
# 3. **str** (String: Collection of letters, numbers and symbols)
# 4. **bool** (Boolean: `True` or `False`)
#
# you can check the type of any data.

# %%
print(type(1))
print(type(1.0))
print(type('a'))
print(type(False))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# BTW, we are using `=` sign, and we don't even know it's name.
# It is called **Assignment operator**. Yes, we learned the name in the first class.
#
# `name = value`
# Here, `=` tells python to store `value` in a box named `name`. That's so simple.
#
# > Do not read it like "~~NAME equal to VALUE~~". Instead, it is read like "name gets the value of value" or, "store value in name"
#
# This sign can also do some creepy things 👻.
# ```python
# choco = 4 + 6        # stores 10
# choco = choco + 5    # adds 5 with previous choco value 10 and store 15
# choco = choco - 9    # subtracts 9 from previous choco value and store 6
# ```
# At first glance, this line may look strange.
# `choco = choco + 5`
# you might think,
# > how can choco be equal to choco + 5?
#
# But remember this is not equal sign. This is **assignment operator**. It tells python to calculate right side
# and then store the value on the left side.
#
# Look at the current value of choco (10).
# 1. Calculate 10 + 5 → 15.
# 2. Store 15 back into choco.
# 3. Now choco contains 15.
#
# The same thing can be done shortly.

# %%
choco = 4 + 6 # stores 10
choco += 5    # adds 5 with previous choco value 10 and store 15
choco -= 9    # subtracts 9 from previous choco value and store 6
print(choco)
# Out:
# 6

# %% [markdown]
# These are called **Assignment operators**.
# There are several of these:
# - ` =` assignment
# - `+=` add and assign
# - `-=` subtract and assign
# - `*=` multiply and assign
# - `/=` divide and assign
# - `...` most of the operators can be used like this.
#
#
# Practice:

# %%
x = 4
x += x**2 + (x - 1)*x - 7
# Is the value of x is even?

# %%
# Area of a triangle
a, b, c = 3, 4, 5
s = (a + b + c) / 2

area = (s * (s-a) * (s-b) * (s-c)) ** 0.5
print(area)
# Out:
# 6.0

# %% [markdown]
# > Now can you do the `Supercalifragilisticexpialidocious` again? 😄
#
# <br>
#
# powered by `//>_<` and `proBOT`
